# %% [markdown]
# # Training and Testing Model Predictions

# %%
#importing packages

import sys, os
import pickle
import numpy as np
import pandas as pd

from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.model_selection import cross_val_score

sys.path.append(os.path.abspath(os.path.join('..', 'utils')))
from utility import evaluate_cat_models

# %%
# initialize models

gnb = GaussianNB()
tree = DecisionTreeClassifier()
forest = RandomForestClassifier()
gradient_boost = GradientBoostingClassifier()
ada_boost = AdaBoostClassifier()

# %% [markdown]
# ### Oversampling model

# %%
#importing datasets
train_set_os = pd.read_csv('../Data/ProcessedData/train_set_os.csv')
test_set_os = pd.read_csv('../Data/ProcessedData/test_set_os.csv')
train_set_os.head()
# Out:
#    Gender       Age  Driving_License  Region_Code  Previously_Insured  \
# 0       0 -1.173108                1     0.907074                   1
# 1       1 -0.685123                1     1.144772                   1
# 2       0 -1.312532                1     0.273213                   1
# 3       1  0.709118                1     1.857865                   0
# 4       0  2.173072                1     0.114748                   0
#
#    Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0            1               0        0.995575              1.014452
# 1            1               0        0.425313              0.871351
# 2            1               0       -0.461971              0.871351
# 3            0               1        0.036527             -1.382476
# 4            0               1        0.404387             -1.382476
#
#     Vintage  Response
# 0  0.320696         0
# 1  1.611185         0
# 2  0.894247         0
# 3 -1.053436         0
# 4 -0.874201         0

# %%
X_train_os = train_set_os.drop('Response', axis=1)
y_train_os = train_set_os['Response']
X_test_os = test_set_os.drop('Response', axis=1)
y_test_os = test_set_os['Response']

# %%
model_list = [tree, gnb, forest, gradient_boost, ada_boost]

evaluate_cat_models(model_list, X_train_os, X_test_os, y_train_os, y_test_os, cv=5)
# Out:
# Fitting DecisionTreeClassifier()
# Done with fitting....
# DecisionTreeClassifier() cross validation
# Done with cross validation
#
#
# Fitting GaussianNB()
# Done with fitting....
# GaussianNB() cross validation
# Done with cross validation
#
#
# Fitting RandomForestClassifier()
# Done with fitting....
# RandomForestClassifier() cross validation
# Done with cross validation
#
#
# Fitting GradientBoostingClassifier()
# Done with fitting....
# GradientBoostingClassifier() cross validation
# Done with cross validation
#
#
# Fitting AdaBoostClassifier()
# Done with fitting....
# AdaBoostClassifier() cross validation
# Done with cross validation
#                                DecisionTreeClassifier()  GaussianNB()  \
# Cross Validated Accuracy Mean                  0.943966      0.784341
# Cross Validated Accuracy Std                   0.001117      0.001344
# Accuracy Score                                 0.593966      0.783464
# Precision Score                                0.748814      0.705194
# Recall Score                                   0.282792      0.974187
# F1 Score                                       0.410542      0.818148
#
#                                RandomForestClassifier()  \
# Cross Validated Accuracy Mean                  0.949923
# Cross Validated Accuracy Std                   0.001077
# Accuracy Score                                 0.595317
# Precision Score                                0.783466
# Recall Score                                   0.263444
# F1 Score                                       0.394302
#
#                                GradientBoostingClassifier()  \
# Cross Validated Accuracy Mean                      0.798536
# Cross Validated Accuracy Std                       0.001749
# Accuracy Score                                     0.797677
# Precision Score                                    0.736805
# Recall Score                                       0.926204
# F1 Score                                           0.820719
#
#                                AdaBoostClassifier()
# Cross Validated Accuracy Mean              0.796954
# Cross Validated Accuracy Std               0.001537
# Accuracy Score                             0.795393
# Precision Score                            0.729137
# Recall Score                               0.939969
# F1 Score                                   0.821238

# %% [markdown]
# ### Undersampling

# %%
#importing datasets
train_set_us = pd.read_csv('../Data/ProcessedData/train_set_us.csv')
test_set_us = pd.read_csv('../Data/ProcessedData/test_set_us.csv')
train_set_us.head()
# Out:
#    Gender       Age  Driving_License  Region_Code  Previously_Insured  \
# 0       0 -0.125850                1     1.694903                   1
# 1       1 -1.101418                1    -0.678984                   1
# 2       0  0.013516                1     0.112311                   0
# 3       0  1.755601                1     0.112311                   0
# 4       1  1.407184                1     0.112311                   0
#
#    Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0            0               0       -1.610919             -1.331072
# 1            1               0       -0.029919              0.869464
# 2            1               0       -1.610919             -1.832008
# 3            0               1       -0.363326              0.368529
# 4            0               1        2.100059             -1.384744
#
#     Vintage  Response
# 0 -0.502065         0
# 1 -0.800362         0
# 2  1.299644         0
# 3  0.703052         0
# 4  0.416687         0

# %%
X_train_us = train_set_us.drop('Response', axis=1)
y_train_us = train_set_us['Response']
X_test_us = test_set_us.drop('Response', axis=1)
y_test_us = test_set_us['Response']

# %%
model_list = [tree, gnb, forest, gradient_boost, ada_boost]

evaluate_cat_models(model_list, X_train_us, X_test_us, y_train_us, y_test_us, cv=5)
# Out:
# Fitting DecisionTreeClassifier()
# Done with fitting....
# DecisionTreeClassifier() cross validation
# Done with cross validation
#
#
# Fitting GaussianNB()
# Done with fitting....
# GaussianNB() cross validation
# Done with cross validation
#
#
# Fitting RandomForestClassifier()
# Done with fitting....
# RandomForestClassifier() cross validation
# Done with cross validation
#
#
# Fitting GradientBoostingClassifier()
# Done with fitting....
# GradientBoostingClassifier() cross validation
# Done with cross validation
#
#
# Fitting AdaBoostClassifier()
# Done with fitting....
# AdaBoostClassifier() cross validation
# Done with cross validation
#                                DecisionTreeClassifier()  GaussianNB()  \
# Cross Validated Accuracy Mean                  0.714812      0.784828
# Cross Validated Accuracy Std                   0.003733      0.001484
# Accuracy Score                                 0.714610      0.782900
# Precision Score                                0.718778      0.704634
# Recall Score                                   0.705087      0.974134
# F1 Score                                       0.711866      0.817752
#
#                                RandomForestClassifier()  \
# Cross Validated Accuracy Mean                  0.782386
# Cross Validated Accuracy Std                   0.003126
# Accuracy Score                                 0.778409
# Precision Score                                0.732574
# Recall Score                                   0.876948
# F1 Score                                       0.798286
#
#                                GradientBoostingClassifier()  \
# Cross Validated Accuracy Mean                      0.796611
# Cross Validated Accuracy Std                       0.002424
# Accuracy Score                                     0.795022
# Precision Score                                    0.733271
# Recall Score                                       0.927381
# F1 Score                                           0.818981
#
#                                AdaBoostClassifier()
# Cross Validated Accuracy Mean              0.795917
# Cross Validated Accuracy Std               0.002428
# Accuracy Score                             0.793182
# Precision Score                            0.726354
# Recall Score                               0.940801
# F1 Score                                   0.819785

# %% [markdown]
# ### Smote

# %%
#importing datasets
train_set_sm = pd.read_csv('../Data/ProcessedData/train_set_sm.csv')
test_set_sm = pd.read_csv('../Data/ProcessedData/test_set_sm.csv')
train_set_sm.head()
# Out:
#    Gender       Age  Driving_License  Region_Code  Previously_Insured  \
# 0       0 -1.204014                1     0.944521                   1
# 1       1 -0.694981                1     1.193767                   1
# 2       0 -1.349452                1     0.279865                   1
# 3       1  0.759399                1     1.941505                   0
# 4       0  2.286497                1     0.113701                   0
#
#    Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0            1               0        1.005682              1.021798
# 1            1               0        0.430212              0.877823
# 2            1               0       -0.465176              0.877823
# 3            0               1        0.037875             -1.389772
# 4            0               1        0.409095             -1.389772
#
#     Vintage  Response
# 0  0.324447         0
# 1  1.623882         0
# 2  0.901974         0
# 3 -1.059211         0
# 4 -0.878734         0

# %%
X_train_sm = train_set_sm.drop('Response', axis=1)
y_train_sm = train_set_sm['Response']
X_test_sm = test_set_sm.drop('Response', axis=1)
y_test_sm = test_set_sm['Response']

# %%
model_list = [tree, gnb, forest, gradient_boost, ada_boost]

evaluate_cat_models(model_list, X_train_sm, X_test_sm, y_train_sm, y_test_sm, cv=5)
# Out:
# Fitting DecisionTreeClassifier()
# Done with fitting....
# DecisionTreeClassifier() cross validation
# Done with cross validation
#
#
# Fitting GaussianNB()
# Done with fitting....
# GaussianNB() cross validation
# Done with cross validation
#
#
# Fitting RandomForestClassifier()
# Done with fitting....
# RandomForestClassifier() cross validation
# Done with cross validation
#
#
# Fitting GradientBoostingClassifier()
# Done with fitting....
# GradientBoostingClassifier() cross validation
# Done with cross validation
#
#
# Fitting AdaBoostClassifier()
# Done with fitting....
# AdaBoostClassifier() cross validation
# Done with cross validation
#                                DecisionTreeClassifier()  GaussianNB()  \
# Cross Validated Accuracy Mean                  0.872417      0.777103
# Cross Validated Accuracy Std                   0.073267      0.001904
# Accuracy Score                                 0.773521      0.775977
# Precision Score                                0.695683      0.702348
# Recall Score                                   0.972410      0.957914
# F1 Score                                       0.811093      0.810461
#
#                                RandomForestClassifier()  \
# Cross Validated Accuracy Mean                  0.879413
# Cross Validated Accuracy Std                   0.066333
# Accuracy Score                                 0.793183
# Precision Score                                0.716956
# Recall Score                                   0.968857
# F1 Score                                       0.824087
#
#                                GradientBoostingClassifier()  \
# Cross Validated Accuracy Mean                      0.836791
# Cross Validated Accuracy Std                       0.037962
# Accuracy Score                                     0.777590
# Precision Score                                    0.694605
# Recall Score                                       0.990803
# F1 Score                                           0.816677
#
#                                AdaBoostClassifier()
# Cross Validated Accuracy Mean              0.823659
# Cross Validated Accuracy Std               0.031696
# Accuracy Score                             0.793534
# Precision Score                            0.715183
# Recall Score                               0.975590
# F1 Score                                   0.825333
