# %% [markdown]
# # Training and Testing Model Predictions

# %%
#importing packages

import sys, os
import pickle
import numpy as np
import pandas as pd

from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.model_selection import cross_val_score

sys.path.append(os.path.abspath(os.path.join('..', 'utils')))
from utility import evaluate_cat_models

# %%
# initialize models

gnb = GaussianNB()
tree = DecisionTreeClassifier()
forest = RandomForestClassifier()
gradient_boost = GradientBoostingClassifier()
ada_boost = AdaBoostClassifier()

# %% [markdown]
# ### Oversampling model

# %%
#importing datasets
train_set_os = pd.read_csv('../Data/ProcessedData/train_set_os.csv')
test_set_os = pd.read_csv('../Data/ProcessedData/test_set_os.csv')
train_set_os.head()
# Out:
#    Gender       Age  Driving_License  Region_Code  Previously_Insured  \
# 0       1 -0.334628                1     1.539172                   0
# 1       0 -1.170958                1    -0.993342                   1
# 2       1  0.850173                1     0.114633                   0
# 3       0 -0.752793                1     1.776595                   0
# 4       1  1.198644                1     1.618313                   1
#
#    Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0            0               1        0.720770             -1.385233
# 1            1               0       -1.584491              0.870169
# 2            0               1       -0.188064              0.368969
# 3            1               0       -0.157233              0.870169
# 4            0               0       -0.038770              0.368969
#
#     Vintage  Response
# 0 -0.851489         0
# 1  0.332837         0
# 2  0.117505         0
# 3  0.021802         0
# 4  0.320874         0

# %%
X_train_os = train_set_os.drop('Response', axis=1)
y_train_os = train_set_os['Response']
X_test_os = test_set_os.drop('Response', axis=1)
y_test_os = test_set_os['Response']

# %%
model_list = [tree, gnb, forest, gradient_boost, ada_boost]

evaluate_cat_models(model_list, X_train_os, X_test_os, y_train_os, y_test_os, cv=5)
# Out:
# Fitting DecisionTreeClassifier()
# Done with fitting....
# DecisionTreeClassifier() cross validation
# Done with cross validation
#
#
# Fitting GaussianNB()
# Done with fitting....
# GaussianNB() cross validation
# Done with cross validation
#
#
# Fitting RandomForestClassifier()
# Done with fitting....
# RandomForestClassifier() cross validation
# Done with cross validation
#
#
# Fitting GradientBoostingClassifier()
# Done with fitting....
# GradientBoostingClassifier() cross validation
# Done with cross validation
#
#
# Fitting AdaBoostClassifier()
# Done with fitting....
# AdaBoostClassifier() cross validation
# Done with cross validation
#                                DecisionTreeClassifier()  GaussianNB()  \
# Cross Validated Accuracy Mean                  0.943692      0.784706
# Cross Validated Accuracy Std                   0.000877      0.000784
# Accuracy Score                                 0.598272      0.783007
# Precision Score                                0.751230      0.704155
# Recall Score                                   0.293854      0.976128
# F1 Score                                       0.422458      0.818130
#
#                                RandomForestClassifier()  \
# Cross Validated Accuracy Mean                  0.949859
# Cross Validated Accuracy Std                   0.000842
# Accuracy Score                                 0.598190
# Precision Score                                0.787254
# Recall Score                                   0.269102
# F1 Score                                       0.401099
#
#                                GradientBoostingClassifier()  \
# Cross Validated Accuracy Mean                      0.797983
# Cross Validated Accuracy Std                       0.000794
# Accuracy Score                                     0.798972
# Precision Score                                    0.735298
# Recall Score                                       0.934276
# F1 Score                                           0.822930
#
#                                AdaBoostClassifier()
# Cross Validated Accuracy Mean              0.796407
# Cross Validated Accuracy Std               0.000783
# Accuracy Score                             0.796279
# Precision Score                            0.730101
# Recall Score                               0.940080
# F1 Score                                   0.821891

# %% [markdown]
# ### Undersampling

# %%
#importing datasets
train_set_us = pd.read_csv('../Data/ProcessedData/train_set_us.csv')
test_set_us = pd.read_csv('../Data/ProcessedData/test_set_us.csv')
train_set_us.head()
# Out:
#    Gender       Age  Driving_License  Region_Code  Previously_Insured  \
# 0       1 -0.539194                1     0.116811                   1
# 1       0 -0.956968                1     0.274653                   1
# 2       0 -1.235484                1     0.116811                   1
# 3       0 -1.165855                1     0.116811                   0
# 4       0  2.037081                1     1.537387                   1
#
#    Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0            1               0        0.015827              0.868155
# 1            1               0        0.125220              0.868155
# 2            1               0        0.086167              1.011236
# 3            1               0        1.869439              0.868155
# 4            0               0        2.589444             -1.385372
#
#     Vintage  Response
# 0  1.553297         0
# 1 -1.414810         0
# 2  0.404353         0
# 3  0.117117         0
# 4  1.349838         0

# %%
X_train_us = train_set_us.drop('Response', axis=1)
y_train_us = train_set_us['Response']
X_test_us = test_set_us.drop('Response', axis=1)
y_test_us = test_set_us['Response']

# %%
model_list = [tree, gnb, forest, gradient_boost, ada_boost]

evaluate_cat_models(model_list, X_train_us, X_test_us, y_train_us, y_test_us, cv=5)
# Out:
# Fitting DecisionTreeClassifier()
# Done with fitting....
# DecisionTreeClassifier() cross validation
# Done with cross validation
#
#
# Fitting GaussianNB()
# Done with fitting....
# GaussianNB() cross validation
# Done with cross validation
#
#
# Fitting RandomForestClassifier()
# Done with fitting....
# RandomForestClassifier() cross validation
# Done with cross validation
#
#
# Fitting GradientBoostingClassifier()
# Done with fitting....
# GradientBoostingClassifier() cross validation
# Done with cross validation
#
#
# Fitting AdaBoostClassifier()
# Done with fitting....
# AdaBoostClassifier() cross validation
# Done with cross validation
#                                DecisionTreeClassifier()  GaussianNB()  \
# Cross Validated Accuracy Mean                  0.712738      0.783210
# Cross Validated Accuracy Std                   0.002548      0.002262
# Accuracy Score                                 0.712523      0.779052
# Precision Score                                0.716118      0.700422
# Recall Score                                   0.704207      0.975215
# F1 Score                                       0.710112      0.815286
#
#                                RandomForestClassifier()  \
# Cross Validated Accuracy Mean                  0.783250
# Cross Validated Accuracy Std                   0.002676
# Accuracy Score                                 0.779378
# Precision Score                                0.733636
# Recall Score                                   0.877269
# F1 Score                                       0.799049
#
#                                GradientBoostingClassifier()  \
# Cross Validated Accuracy Mean                      0.797659
# Cross Validated Accuracy Std                       0.002745
# Accuracy Score                                     0.794706
# Precision Score                                    0.732265
# Recall Score                                       0.929123
# F1 Score                                           0.819031
#
#                                AdaBoostClassifier()
# Cross Validated Accuracy Mean              0.796660
# Cross Validated Accuracy Std               0.003124
# Accuracy Score                             0.791064
# Precision Score                            0.726389
# Recall Score                               0.933906
# F1 Score                                   0.817179

# %% [markdown]
# ### Smote

# %%
#importing datasets
train_set_sm = pd.read_csv('../Data/ProcessedData/train_set_sm.csv')
test_set_sm = pd.read_csv('../Data/ProcessedData/test_set_sm.csv')
train_set_sm.head()
# Out:
#    Gender       Age  Driving_License  Region_Code  Previously_Insured  \
# 0       1 -0.331165                1     1.609263                   0
# 1       0 -1.203193                1    -1.045520                   1
# 2       1  0.904207                1     0.115948                   0
# 3       0 -0.767179                1     1.858149                   0
# 4       1  1.267552                1     1.692225                   1
#
#    Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0            0               1        0.727775             -1.388237
# 1            1               0       -1.598957              0.877675
# 2            0               1       -0.189524              0.374139
# 3            1               0       -0.158406              0.877675
# 4            0               0       -0.038839              0.374139
#
#     Vintage  Response
# 0 -0.856540         0
# 1  0.336057         0
# 2  0.119221         0
# 3  0.022850         0
# 4  0.324011         0

# %%
X_train_sm = train_set_sm.drop('Response', axis=1)
y_train_sm = train_set_sm['Response']
X_test_sm = test_set_sm.drop('Response', axis=1)
y_test_sm = test_set_sm['Response']

# %%
model_list = [tree, gnb, forest, gradient_boost, ada_boost]

evaluate_cat_models(model_list, X_train_sm, X_test_sm, y_train_sm, y_test_sm, cv=5)
# Out:
# Fitting DecisionTreeClassifier()
# Done with fitting....
# DecisionTreeClassifier() cross validation
# Done with cross validation
#
#
# Fitting GaussianNB()
# Done with fitting....
# GaussianNB() cross validation
# Done with cross validation
#
#
# Fitting RandomForestClassifier()
# Done with fitting....
# RandomForestClassifier() cross validation
# Done with cross validation
#
#
# Fitting GradientBoostingClassifier()
# Done with fitting....
# GradientBoostingClassifier() cross validation
# Done with cross validation
#
#
# Fitting AdaBoostClassifier()
# Done with fitting....
# AdaBoostClassifier() cross validation
# Done with cross validation
#                                DecisionTreeClassifier()  GaussianNB()  \
# Cross Validated Accuracy Mean                  0.871681      0.776983
# Cross Validated Accuracy Std                   0.073998      0.002756
# Accuracy Score                                 0.630537      0.774749
# Precision Score                                0.577595      0.700832
# Recall Score                                   0.971681      0.958775
# F1 Score                                       0.724517      0.809758
#
#                                RandomForestClassifier()  \
# Cross Validated Accuracy Mean                  0.879597
# Cross Validated Accuracy Std                   0.065209
# Accuracy Score                                 0.793019
# Precision Score                                0.718405
# Recall Score                                   0.963833
# F1 Score                                       0.823216
#
#                                GradientBoostingClassifier()  \
# Cross Validated Accuracy Mean                      0.837067
# Cross Validated Accuracy Std                       0.037713
# Accuracy Score                                     0.777099
# Precision Score                                    0.694191
# Recall Score                                       0.990570
# F1 Score                                           0.816311
#
#                                AdaBoostClassifier()
# Cross Validated Accuracy Mean              0.823698
# Cross Validated Accuracy Std               0.030366
# Accuracy Score                             0.793369
# Precision Score                            0.714907
# Recall Score                               0.975919
# F1 Score                                   0.825267
